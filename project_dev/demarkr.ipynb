# %% [markdown]
# **To-Do**
# - generator (adaptive unet, already in fastai2)
# - critic (not in fastai2 yet, see old fastai source code)
# -

# %%
from fastai2.basics import *
from fastai2.callback.all import *
from fastai2.vision.all import *

# %%
# ?untar_data

# %%
DATA = Path("data")
CLEAN = Path(DATA/"CelebA/img_align_celeba")

# %%
PILImage.create(CLEAN/np.random.choice(os.listdir(CLEAN)))
# Out:
# PILImage mode=RGB size=178x218
